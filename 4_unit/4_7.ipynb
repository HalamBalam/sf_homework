# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')

# %%
melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3_000_000)]['Regionname'].value_counts()
# Out:
# Northern Metropolitan         2737
# Southern Metropolitan         2520
# Western Metropolitan          2286
# Eastern Metropolitan          1167
# South-Eastern Metropolitan     387
# Eastern Victoria                50
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
melb_data.head(20)
# Out:
#     index      Suburb              Address  Rooms Type      Price Method  \
# 0       0  Abbotsford         85 Turner St      2    h  1480000.0      S
# 1       1  Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 2       2  Abbotsford         5 Charles St      3    h  1465000.0     SP
# 3       3  Abbotsford     40 Federation La      3    h   850000.0     PI
# 4       4  Abbotsford          55a Park St      4    h  1600000.0     VB
# 5       5  Abbotsford       129 Charles St      2    h   941000.0      S
# 6       6  Abbotsford         124 Yarra St      3    h  1876000.0      S
# 7       7  Abbotsford        98 Charles St      2    h  1636000.0      S
# 8       8  Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 9       9  Abbotsford        10 Valiant St      2    h  1097000.0      S
# 10     10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 11     11  Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 12     12  Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 13     13  Abbotsford        45 William St      2    h  1172500.0      S
# 14     14  Abbotsford   7/20 Abbotsford St      1    u   441000.0     SP
# 15     15  Abbotsford        16 William St      2    h  1310000.0      S
# 16     16  Abbotsford          42 Henry St      3    h  1200000.0      S
# 17     17  Abbotsford          78 Yarra St      3    h  1176500.0      S
# 18     18  Abbotsford     196 Nicholson St      3    h   955000.0      S
# 19     19  Abbotsford        42 Valiant St      2    h   890000.0      S
#
#     SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0    Biggin   3/12/2016       2.5  ...    1     202.0         126.0
# 1    Biggin   4/02/2016       2.5  ...    0     156.0          79.0
# 2    Biggin   4/03/2017       2.5  ...    0     134.0         150.0
# 3    Biggin   4/03/2017       2.5  ...    1      94.0         126.0
# 4    Nelson   4/06/2016       2.5  ...    2     120.0         142.0
# 5    Jellis   7/05/2016       2.5  ...    0     181.0         126.0
# 6    Nelson   7/05/2016       2.5  ...    0     245.0         210.0
# 7    Nelson   8/10/2016       2.5  ...    2     256.0         107.0
# 8    Biggin   8/10/2016       2.5  ...    1       0.0         126.0
# 9    Biggin   8/10/2016       2.5  ...    2     220.0          75.0
# 10   Jellis  12/11/2016       2.5  ...    1       0.0         126.0
# 11   Nelson  12/11/2016       2.5  ...    2     214.0         190.0
# 12   Biggin  12/11/2016       2.5  ...    1       0.0          94.0
# 13   Biggin  13/08/2016       2.5  ...    1     195.0         126.0
# 14     Greg  14/05/2016       2.5  ...    1       0.0         126.0
# 15   Jellis  15/10/2016       2.5  ...    2     238.0          97.0
# 16   Jellis  16/07/2016       2.5  ...    1     113.0         110.0
# 17   LITTLE  16/07/2016       2.5  ...    1     138.0         105.0
# 18  Collins  17/09/2016       2.5  ...    0     183.0         126.0
# 19   Biggin  17/09/2016       2.5  ...    1     150.0          73.0
#
#     YearBuilt  CouncilArea  Lattitude  Longtitude             Regionname  \
# 0        1970        Yarra   -37.7996    144.9984  Northern Metropolitan
# 1        1900        Yarra   -37.8079    144.9934  Northern Metropolitan
# 2        1900        Yarra   -37.8093    144.9944  Northern Metropolitan
# 3        1970        Yarra   -37.7969    144.9969  Northern Metropolitan
# 4        2014        Yarra   -37.8072    144.9941  Northern Metropolitan
# 5        1970        Yarra   -37.8041    144.9953  Northern Metropolitan
# 6        1910        Yarra   -37.8024    144.9993  Northern Metropolitan
# 7        1890        Yarra   -37.8060    144.9954  Northern Metropolitan
# 8        1970        Yarra   -37.8008    144.9973  Northern Metropolitan
# 9        1900        Yarra   -37.8010    144.9989  Northern Metropolitan
# 10       1970        Yarra   -37.8110    145.0067  Northern Metropolitan
# 11       2005        Yarra   -37.8085    144.9964  Northern Metropolitan
# 12       2009        Yarra   -37.8078    144.9965  Northern Metropolitan
# 13       1970        Yarra   -37.8084    144.9973  Northern Metropolitan
# 14       1970        Yarra   -37.8016    144.9988  Northern Metropolitan
# 15       1890        Yarra   -37.8090    144.9976  Northern Metropolitan
# 16       1880        Yarra   -37.8056    144.9930  Northern Metropolitan
# 17       1890        Yarra   -37.8021    144.9965  Northern Metropolitan
# 18       1970        Yarra   -37.8022    144.9975  Northern Metropolitan
# 19       1985        Yarra   -37.8011    145.0004  Northern Metropolitan
#
#     Propertycount         Coordinates
# 0            4019  -37.7996, 144.9984
# 1            4019  -37.8079, 144.9934
# 2            4019  -37.8093, 144.9944
# 3            4019  -37.7969, 144.9969
# 4            4019  -37.8072, 144.9941
# 5            4019  -37.8041, 144.9953
# 6            4019  -37.8024, 144.9993
# 7            4019   -37.806, 144.9954
# 8            4019  -37.8008, 144.9973
# 9            4019   -37.801, 144.9989
# 10           4019   -37.811, 145.0067
# 11           4019  -37.8085, 144.9964
# 12           4019  -37.8078, 144.9965
# 13           4019  -37.8084, 144.9973
# 14           4019  -37.8016, 144.9988
# 15           4019   -37.809, 144.9976
# 16           4019   -37.8056, 144.993
# 17           4019  -37.8021, 144.9965
# 18           4019  -37.8022, 144.9975
# 19           4019  -37.8011, 145.0004
#
# [20 rows x 23 columns]
